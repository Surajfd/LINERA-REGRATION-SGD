# %% [markdown]
# In \[1\]:
#
#     import numpy as np
#     import pandas as pd
#     import matplotlib. pyplot as plt
#
# In \[2\]:
#
#     bankmarketing = pd.read_csv("bank_marketing.csv")
#
# In \[3\]:
#
#     bankmarketing
#
# Out\[3\]:
#
# |      | Unnamed: 0 | age | job         | marital | education | default | balance | housing | loan | contact   | day | month | duration | campaign | pdays | previous | poutcome | deposit |
# |------|------------|-----|-------------|---------|-----------|---------|---------|---------|------|-----------|-----|-------|----------|----------|-------|----------|----------|---------|
# | 0    | 0          | 41  | services    | married | unknown   | no      | 88      | yes     | no   | cellular  | 11  | may   | 105      | 1        | 336   | 2        | failure  | no      |
# | 1    | 1          | 56  | technician  | married | secondary | no      | 1938    | no      | yes  | cellular  | 26  | feb   | 229      | 1        | 192   | 4        | success  | yes     |
# | 2    | 2          | 30  | services    | single  | secondary | no      | 245     | no      | yes  | cellular  | 8   | jul   | 187      | 2        | -1    | 0        | unknown  | no      |
# | 3    | 3          | 34  | management  | single  | tertiary  | no      | 1396    | yes     | no   | cellular  | 17  | jul   | 630      | 1        | -1    | 0        | unknown  | no      |
# | 4    | 4          | 29  | technician  | single  | secondary | no      | -13     | yes     | no   | cellular  | 14  | may   | 512      | 3        | -1    | 0        | unknown  | no      |
# | ...  | ...        | ... | ...         | ...     | ...       | ...     | ...     | ...     | ...  | ...       | ... | ...   | ...      | ...      | ...   | ...      | ...      | ...     |
# | 5576 | 5576       | 48  | admin.      | married | secondary | no      | 2235    | yes     | yes  | unknown   | 15  | may   | 755      | 2        | -1    | 0        | unknown  | no      |
# | 5577 | 5577       | 40  | blue-collar | married | primary   | no      | -388    | yes     | no   | cellular  | 4   | may   | 195      | 3        | 340   | 1        | failure  | no      |
# | 5578 | 5578       | 27  | student     | single  | secondary | no      | 91      | no      | no   | telephone | 4   | dec   | 157      | 6        | 95    | 37       | other    | no      |
# | 5579 | 5579       | 46  | blue-collar | married | secondary | no      | 1568    | yes     | no   | cellular  | 2   | jun   | 310      | 1        | 55    | 6        | other    | yes     |
# | 5580 | 5580       | 39  | services    | married | secondary | no      | 0       | yes     | no   | cellular  | 8   | may   | 503      | 1        | -1    | 0        | unknown  | no      |
#
# 5581 rows × 18 columns
#
# In \[4\]:
#
#     bankmarketing.shape
#
# Out\[4\]:
#
#     (5581, 18)
#
# In \[6\]:
#
#     bankmarketing.head()
#
# Out\[6\]:
#
# |     | Unnamed: 0 | age | job        | marital | education | default | balance | housing | loan | contact  | day | month | duration | campaign | pdays | previous | poutcome | deposit |
# |-----|------------|-----|------------|---------|-----------|---------|---------|---------|------|----------|-----|-------|----------|----------|-------|----------|----------|---------|
# | 0   | 0          | 41  | services   | married | unknown   | no      | 88      | yes     | no   | cellular | 11  | may   | 105      | 1        | 336   | 2        | failure  | no      |
# | 1   | 1          | 56  | technician | married | secondary | no      | 1938    | no      | yes  | cellular | 26  | feb   | 229      | 1        | 192   | 4        | success  | yes     |
# | 2   | 2          | 30  | services   | single  | secondary | no      | 245     | no      | yes  | cellular | 8   | jul   | 187      | 2        | -1    | 0        | unknown  | no      |
# | 3   | 3          | 34  | management | single  | tertiary  | no      | 1396    | yes     | no   | cellular | 17  | jul   | 630      | 1        | -1    | 0        | unknown  | no      |
# | 4   | 4          | 29  | technician | single  | secondary | no      | -13     | yes     | no   | cellular | 14  | may   | 512      | 3        | -1    | 0        | unknown  | no      |
#
# In \[7\]:
#
#     bankmarketing.tail()
#
# Out\[7\]:
#
# |      | Unnamed: 0 | age | job         | marital | education | default | balance | housing | loan | contact   | day | month | duration | campaign | pdays | previous | poutcome | deposit |
# |------|------------|-----|-------------|---------|-----------|---------|---------|---------|------|-----------|-----|-------|----------|----------|-------|----------|----------|---------|
# | 5576 | 5576       | 48  | admin.      | married | secondary | no      | 2235    | yes     | yes  | unknown   | 15  | may   | 755      | 2        | -1    | 0        | unknown  | no      |
# | 5577 | 5577       | 40  | blue-collar | married | primary   | no      | -388    | yes     | no   | cellular  | 4   | may   | 195      | 3        | 340   | 1        | failure  | no      |
# | 5578 | 5578       | 27  | student     | single  | secondary | no      | 91      | no      | no   | telephone | 4   | dec   | 157      | 6        | 95    | 37       | other    | no      |
# | 5579 | 5579       | 46  | blue-collar | married | secondary | no      | 1568    | yes     | no   | cellular  | 2   | jun   | 310      | 1        | 55    | 6        | other    | yes     |
# | 5580 | 5580       | 39  | services    | married | secondary | no      | 0       | yes     | no   | cellular  | 8   | may   | 503      | 1        | -1    | 0        | unknown  | no      |
#
# In \[9\]:
#
#     bankmarketing.iloc[:1,10]
#
# Out\[9\]:
#
#     0    11
#     Name: day, dtype: int64
#
# In \[10\]:
#
#     bankmarketing.describe()
#
# Out\[10\]:
#
# |       | Unnamed: 0  | age         | balance      | day         | duration    | campaign    | pdays       | previous    |
# |-------|-------------|-------------|--------------|-------------|-------------|-------------|-------------|-------------|
# | count | 5581.000000 | 5581.000000 | 5581.000000  | 5581.000000 | 5581.000000 | 5581.000000 | 5581.000000 | 5581.000000 |
# | mean  | 2790.000000 | 41.169683   | 1514.736786  | 15.693603   | 368.175954  | 2.507436    | 52.534313   | 0.849669    |
# | std   | 1611.240257 | 11.926044   | 3266.534626  | 8.461086    | 344.131053  | 2.770717    | 110.754995  | 2.311684    |
# | min   | 0.000000    | 18.000000   | -3058.000000 | 1.000000    | 3.000000    | 1.000000    | -1.000000   | 0.000000    |
# | 25%   | 1395.000000 | 32.000000   | 110.000000   | 8.000000    | 137.000000  | 1.000000    | -1.000000   | 0.000000    |
# | 50%   | 2790.000000 | 39.000000   | 542.000000   | 15.000000   | 254.000000  | 2.000000    | -1.000000   | 0.000000    |
# | 75%   | 4185.000000 | 49.000000   | 1747.000000  | 22.000000   | 485.000000  | 3.000000    | 57.000000   | 1.000000    |
# | max   | 5580.000000 | 93.000000   | 81204.000000 | 31.000000   | 3284.000000 | 63.000000   | 842.000000  | 41.000000   |
#
# In \[12\]:
#
#     bankmarketing.info()
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 5581 entries, 0 to 5580
#     Data columns (total 18 columns):
#      #   Column      Non-Null Count  Dtype
#     ---  ------      --------------  -----
#      0   Unnamed: 0  5581 non-null   int64
#      1   age         5581 non-null   int64
#      2   job         5581 non-null   object
#      3   marital     5581 non-null   object
#      4   education   5581 non-null   object
#      5   default     5581 non-null   object
#      6   balance     5581 non-null   int64
#      7   housing     5581 non-null   object
#      8   loan        5581 non-null   object
#      9   contact     5581 non-null   object
#      10  day         5581 non-null   int64
#      11  month       5581 non-null   object
#      12  duration    5581 non-null   int64
#      13  campaign    5581 non-null   int64
#      14  pdays       5581 non-null   int64
#      15  previous    5581 non-null   int64
#      16  poutcome    5581 non-null   object
#      17  deposit     5581 non-null   object
#     dtypes: int64(8), object(10)
#     memory usage: 785.0+ KB
#
# In \[20\]:
#
#     bankmarketing.isnull().values.any()
#
# Out\[20\]:
#
#     False
#
# In \[21\]:
#
#     bankmarketing.isnull()
#
# Out\[21\]:
#
# |      | Unnamed: 0 | age   | job   | marital | education | default | balance | housing | loan  | contact | day   | month | duration | campaign | pdays | previous | poutcome | deposit |
# |------|------------|-------|-------|---------|-----------|---------|---------|---------|-------|---------|-------|-------|----------|----------|-------|----------|----------|---------|
# | 0    | False      | False | False | False   | False     | False   | False   | False   | False | False   | False | False | False    | False    | False | False    | False    | False   |
# | 1    | False      | False | False | False   | False     | False   | False   | False   | False | False   | False | False | False    | False    | False | False    | False    | False   |
# | 2    | False      | False | False | False   | False     | False   | False   | False   | False | False   | False | False | False    | False    | False | False    | False    | False   |
# | 3    | False      | False | False | False   | False     | False   | False   | False   | False | False   | False | False | False    | False    | False | False    | False    | False   |
# | 4    | False      | False | False | False   | False     | False   | False   | False   | False | False   | False | False | False    | False    | False | False    | False    | False   |
# | ...  | ...        | ...   | ...   | ...     | ...       | ...     | ...     | ...     | ...   | ...     | ...   | ...   | ...      | ...      | ...   | ...      | ...      | ...     |
# | 5576 | False      | False | False | False   | False     | False   | False   | False   | False | False   | False | False | False    | False    | False | False    | False    | False   |
# | 5577 | False      | False | False | False   | False     | False   | False   | False   | False | False   | False | False | False    | False    | False | False    | False    | False   |
# | 5578 | False      | False | False | False   | False     | False   | False   | False   | False | False   | False | False | False    | False    | False | False    | False    | False   |
# | 5579 | False      | False | False | False   | False     | False   | False   | False   | False | False   | False | False | False    | False    | False | False    | False    | False   |
# | 5580 | False      | False | False | False   | False     | False   | False   | False   | False | False   | False | False | False    | False    | False | False    | False    | False   |
#
# 5581 rows × 18 columns
#
# In \[25\]:
#
#     bankmarketing.groupby(by = 'pdays').mean()
#
# Out\[25\]:
#
# Unnamed: 0
#
# age
#
# balance
#
# day
#
# duration
#
# campaign
#
# previous
#
# pdays
#
# -1
#
# 2764.267118
#
# 40.978708
#
# 1393.090975
#
# 16.06678
#
# 378.719816
#
# 2.715461
#
# 0.000000
#
# 1
#
# 2265.500000
#
# 55.333333
#
# 651.000000
#
# 4.00000
#
# 247.666667
#
# 1.666667
#
# 4.833333
#
# 2
#
# 2962.400000
#
# 40.800000
#
# 511.200000
#
# 30.00000
#
# 215.000000
#
# 1.400000
#
# 5.000000
#
# 5
#
# 3632.500000
#
# 30.500000
#
# 1938.500000
#
# 2.00000
#
# 108.500000
#
# 2.000000
#
# 2.000000
#
# 6
#
# 2261.000000
#
# 58.000000
#
# 1387.000000
#
# 3.00000
#
# 140.000000
#
# 6.000000
#
# 6.000000
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# 792
#
# 102.000000
#
# 60.000000
#
# 975.000000
#
# 16.00000
#
# 303.000000
#
# 1.000000
#
# 1.000000
#
# 804
#
# 2194.000000
#
# 45.000000
#
# 2048.000000
#
# 18.00000
#
# 310.000000
#
# 1.000000
#
# 1.000000
#
# 826
#
# 3017.000000
#
# 47.000000
#
# 1387.000000
#
# 14.00000
#
# 158.000000
#
# 1.000000
#
# 1.000000
#
# 828
#
# 4524.000000
#
# 34.000000
#
# 320.000000
#
# 12.00000
#
# 352.000000
#
# 1.000000
#
# 2.000000
#
# 842
#
# 3055.000000
#
# 31.000000
#
# 243.000000
#
# 23.00000
#
# 305.000000
#
# 2.000000
#
# 1.000000
#
# 379 rows × 7 columns
#
# In \[26\]:
#
#     bankmarketing.isnull().sum().sum()
#
# Out\[26\]:
#
#     0
#
# In \[18\]:
#
#     import matplotlib.pyplot as plt
#
# In \[30\]:
#
#     bankmarketing = [1,2,3,4,5,6,12,14,15,16,30,60]
#
# In \[32\]:
#
#     plt.boxplot(bankmarketing)
#
# Out\[32\]:
#
#     {'whiskers': [<matplotlib.lines.Line2D at 0x7fd3563da700>,
#       <matplotlib.lines.Line2D at 0x7fd3563daa60>],
#      'caps': [<matplotlib.lines.Line2D at 0x7fd3563dadc0>,
#       <matplotlib.lines.Line2D at 0x7fd3563e7160>],
#      'boxes': [<matplotlib.lines.Line2D at 0x7fd3563da3a0>],
#      'medians': [<matplotlib.lines.Line2D at 0x7fd3563e74c0>],
#      'fliers': [<matplotlib.lines.Line2D at 0x7fd3563e7820>],
#      'means': []}
#
# ![](data:image/png;base64,...%0A)
#
# In \[35\]:
#
#     plt.boxplot
#
# Out\[35\]:
#
#     <function matplotlib.pyplot.boxplot(x, notch=None, sym=None, vert=None, whis=None, positions=None, widths=None, patch_artist=None, bootstrap=None, usermedians=None, conf_intervals=None, meanline=None, showmeans=None, showcaps=None, showbox=None, showfliers=None, boxprops=None, labels=None, flierprops=None, medianprops=None, meanprops=None, capprops=None, whiskerprops=None, manage_ticks=True, autorange=False, zorder=None, *, data=None)>
#
# In \[38\]:
#
#     import matplotlib.pyplot as plt
#     import numpy as np
#
#     DATA = np.random.rand(150)*700
#     plt.boxplot(bankmarketing)
#
# Out\[38\]:
#
#     {'whiskers': [<matplotlib.lines.Line2D at 0x7fd3562dfd30>,
#       <matplotlib.lines.Line2D at 0x7fd3562ef5b0>],
#      'caps': [<matplotlib.lines.Line2D at 0x7fd35635a1f0>,
#       <matplotlib.lines.Line2D at 0x7fd356230880>],
#      'boxes': [<matplotlib.lines.Line2D at 0x7fd356229ca0>],
#      'medians': [<matplotlib.lines.Line2D at 0x7fd3562309a0>],
#      'fliers': [<matplotlib.lines.Line2D at 0x7fd356509eb0>],
#      'means': []}
#
# ![](data:image/png;base64,...%0A)
#
# In \[39\]:
#
#     from sklearn.datasets import load_iris
#     import pandas as pd
#
# In \[40\]:
#
#     bankmarketing =load_iris
#
# In \[49\]:
#
#     bankmarketing
#
# Out\[49\]:
#
#     <function sklearn.datasets._base.load_iris(*, return_X_y=False, as_frame=False)>
#
# In \[60\]:
#
#     import pandas as pd
#     import numpy as np
#     import function
#
#     bankmarketing= pd.DataFrame(
#                      data = np.c_[bankmarketing['data'],bankmarketing['target']],
#                            columns = bankmarketing['feature_names']+['target'])
#
#     ---------------------------------------------------------------------------
#     ModuleNotFoundError                       Traceback (most recent call last)
#     <ipython-input-60-f4aff22fcfeb> in <module>
#           1 import pandas as pd
#           2 import numpy as np
#     ----> 3 import function
#           4
#           5 bankmarketing= pd.DataFrame(
#
#     ModuleNotFoundError: No module named 'function'
#
# In \[61\]:
#
#     import matplotlib.pyplot as plt
#     plt.plot([x for x in range(0,10)],marker='P')
#
# Out\[61\]:
#
#     [<matplotlib.lines.Line2D at 0x7fd358018910>]
#
# ![](data:image/png;base64,...%0A)
#
# In \[64\]:
#
#     plt.hist([1,2,3,4,5,6,12,14,15,16,30,60,100])
#     plt.show()
#
# ![](data:image/png;base64,...%0A)
#
# In \[65\]:
#
#     labels = ['frogs','blue','hogs','logs']
#     sizes = [1,2,3,4,5,6,12,14,15,16,30,60,10]
#
# In \[67\]:
#
#     bankmarketing
#
# Out\[67\]:
#
#     <function sklearn.datasets._base.load_iris(*, return_X_y=False, as_frame=False)>
#
# In \[68\]:
#
#     labels
#
# Out\[68\]:
#
#     ['frogs', 'blue', 'hogs', 'logs']
#
# In \[73\]:
#
#     import pandas as pd
#     import numpy as no
#     import matplotlib.pyplot as plt  # DHORO X,AND Y IS TWO LIST X = 2,4,6 AND Y = 1,3,5
#
# In \[74\]:
#
#     x = [2,4,6,9,10]
#     y = [1,3,5,12,7]     # AFTER ADD EXTRA VALUE 10,9,12,7
#
# In \[75\]:
#
#     plt.plot(x,y)
#
# Out\[75\]:
#
#     [<matplotlib.lines.Line2D at 0x7fd3587d01f0>]
#
# ![](data:image/png;base64,...%0A)
#
# In \[ \]:
